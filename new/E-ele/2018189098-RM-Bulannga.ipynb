# %% [markdown]
# # libraries

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn import metrics
# %matplotlib inline
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # Import data

# %%
crashes = pd.read_csv('airplane_crashes.csv')
crashes.head(5)
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# ...

# %%
crashes = pd.read_csv('airplane_crashes.csv', names = ['Date',
                                                       'Time',
                                                       'Location',
                                                       'Operator',
                                                       'Flight #',
                                                       'Change Location to Crash_Location',
                                                       'Change Operator to Airline_Operator',
                                                       'Change Type to Aircraft_Type',
                                                       'Change Registration to Registration_Number',
                                                       'Change Aboard to People_Aboard',
                                                       'Change Fatalities to Fatalities_Aboard',
                                                       'Change Ground to Ground_Fatalities',
                                                       'Change Summary to Event_Info.s'], header =None, skiprows=1)
crashes.head(5)
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight # Change Location to Crash_Location  \
# 0    Military - U.S. Army      NaN                     Demonstration
# 1    Military - U.S. Navy      NaN                       Test flight
# 2                 Private        -                               NaN
# 3  Military - German Navy      NaN                               NaN
# 4  Military - German Navy      NaN                               NaN
#
#   Change Operator to Airline_Operator Change Type to Aircraft_Type  \
# 0                    Wright Flyer III                          NaN
# 1                           Dirigible                          NaN
# ...

# %%
#2.3
print('The row count: ', crashes.shape[0])
print('Thhe column count: ', crashes.shape[1])
# Out:
# The row count:  5268
# Thhe column count:  13

# %% [markdown]
# # Inspect data

# %%
#2.4
crashes.head(10)
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
# 5  03/05/1915  01:00                     Tienen, Belgium
# 6  09/03/1915  15:20               Off Cuxhaven, Germany
# 7  07/28/1916    NaN               Near Jambol, Bulgeria
# 8  09/24/1916  01:00                 Billericay, England
# 9  10/01/1916  23:45                Potters Bar, England
#
#                  Operator Flight # Change Location to Crash_Location  \
# 0    Military - U.S. Army      NaN                     Demonstration
# 1    Military - U.S. Navy      NaN                       Test flight
# 2                 Private        -                               NaN
# ...

# %%
crashes.describe(include='all')
# Out:
#               Date   Time           Location  Operator Flight #  \
# count         5268   3049               5248      5250     1069
# unique        4753   1005               4303      2476      724
# top     09/11/2001  15:00  Sao Paulo, Brazil  Aeroflot        -
# freq             4     32                 15       179       67
# mean           NaN    NaN                NaN       NaN      NaN
# std            NaN    NaN                NaN       NaN      NaN
# min            NaN    NaN                NaN       NaN      NaN
# 25%            NaN    NaN                NaN       NaN      NaN
# 50%            NaN    NaN                NaN       NaN      NaN
# 75%            NaN    NaN                NaN       NaN      NaN
# max            NaN    NaN                NaN       NaN      NaN
#
#        Change Location to Crash_Location Change Operator to Airline_Operator  \
# count                               3562                                5241
# ...

# %%
print(crashes.dtypes)
# Out:
# Date                                           object
# Time                                           object
# Location                                       object
# Operator                                       object
# Flight #                                       object
# Change Location to Crash_Location              object
# Change Operator to Airline_Operator            object
# Change Type to Aircraft_Type                   object
# Change Registration to Registration_Number     object
# Change Aboard to People_Aboard                float64
# Change Fatalities to Fatalities_Aboard        float64
# Change Ground to Ground_Fatalities            float64
# Change Summary to Event_Info.s                 object
# dtype: object

# %%
#2.5 
crashes['Date'] = pd.to_datetime(crashes['Date'])

# %%
#updated dataType
print(crashes.dtypes)
# Out:
# Date                                          datetime64[ns]
# Time                                                  object
# Location                                              object
# Operator                                              object
# Flight #                                              object
# Change Location to Crash_Location                     object
# Change Operator to Airline_Operator                   object
# Change Type to Aircraft_Type                          object
# Change Registration to Registration_Number            object
# Change Aboard to People_Aboard                       float64
# Change Fatalities to Fatalities_Aboard               float64
# Change Ground to Ground_Fatalities                   float64
# Change Summary to Event_Info.s                        object
# dtype: object

# %% [markdown]
# # Split date

# %%
#2.6
crashes['Year']= crashes['Date'].dt.year
crashes['Month']= crashes['Date'].dt.month
crashes['Day']= crashes['Date'].dt.day

# %%
#changing position of columns
cols = crashes.columns.tolist() 
new_cols = [['Date','Year','Month', 'Date', 'Time',
                                                       'Location',
                                                       'Operator',
                                                       'Flight #',
                                                       'Change Location to Crash_Location',
                                                       'Change Operator to Airline_Operator',
                                                       'Change Type to Aircraft_Type',
                                                       'Change Registration to Registration_Number',
                                                       'Change Aboard to People_Aboard',
                                                       'Change Fatalities to Fatalities_Aboard',
                                                       'Change Ground to Ground_Fatalities',
                                                       'Change Summary to Event_Info.s']]
crashes = crashes.reindex(columns=new_cols)

# %%
#check data type
print(crashes.dtypes)
# Out:
# Date                                          datetime64[ns]
# Time                                                  object
# Location                                              object
# Operator                                              object
# Flight #                                              object
# Change Location to Crash_Location                     object
# Change Operator to Airline_Operator                   object
# Change Type to Aircraft_Type                          object
# Change Registration to Registration_Number            object
# Change Aboard to People_Aboard                       float64
# Change Fatalities to Fatalities_Aboard               float64
# Change Ground to Ground_Fatalities                   float64
# Change Summary to Event_Info.s                        object
# Year                                                   int64
# Month                                                  int64
# ...

# %% [markdown]
# # Adding a column

# %%
#2.7.1
crashes['Total_Fatalities'] = crashes['Change Fatalities to Fatalities_Aboard'] + crashes['Change Ground to Ground_Fatalities']
crashes['Total_fatalities'].max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total_Fatalities'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
#2.7.2
day_crash= crashes.loc[(crashes[])]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total_Fatalities'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# # Ranking

# %%
#2.8

crashes.rank(ascending=False, method='first').head()
totalSum = crashes.sum(axis=1)
totalSum.rank(ascending=False, method='dense').sort_values().head()
# Out:
#   Date Year Month Date Time Location Operator Flight #  \
# 0  NaN  NaN   NaN  NaN  NaN      NaN      NaN      NaN
# 1  NaN  NaN   NaN  NaN  NaN      NaN      NaN      NaN
# 2  NaN  NaN   NaN  NaN  NaN      NaN      NaN      NaN
# 3  NaN  NaN   NaN  NaN  NaN      NaN      NaN      NaN
# 4  NaN  NaN   NaN  NaN  NaN      NaN      NaN      NaN
#
#   Change Location to Crash_Location Change Operator to Airline_Operator  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
#
#   Change Type to Aircraft_Type Change Registration to Registration_Number  \
# 0                          NaN                                        NaN
# ...

# %%
#2.9
airp_crashes= crashes[crashes['Change Summary to Event_Info.s'] = '%crashes']
airplane = crashes.size()
print ('Percentage of all airplanes: ', Round(int(len(airp_crashes)/float(len(airplane))*100), 2), '%.')

# %% [markdown]
# # Pie chart

# %%
#2.10

airboard = crashes['Change Fatalities to Fatalities_Aboard'].value.counts()
plt.pie(airboard,labels=labels, colors=colors, startangle=90, autopct='%1.1f%%')

fig = plt.gcf()
fig.set_size_inches(6,6)
plt.show()

# %%
#2.16
crashes.isnull().sum()
# Out:
# Date                                          5268
# Year                                          5268
# Month                                         5268
# Date                                          5268
# Time                                          5268
# Location                                      5268
# Operator                                      5268
# Flight #                                      5268
# Change Location to Crash_Location             5268
# Change Operator to Airline_Operator           5268
# Change Type to Aircraft_Type                  5268
# Change Registration to Registration_Number    5268
# Change Aboard to People_Aboard                5268
# Change Fatalities to Fatalities_Aboard        5268
# Change Ground to Ground_Fatalities            5268
# Change Summary to Event_Info.s                5268
# dtype: int64

# %%
crashes.drop(crashes.isnull().sum(), axis=1, inplace=True)

# %%
#checking if droped
crashes.isnull().sum()
# Out:
# Date                                          5268
# Year                                          5268
# Month                                         5268
# Date                                          5268
# Time                                          5268
# Location                                      5268
# Operator                                      5268
# Flight #                                      5268
# Change Location to Crash_Location             5268
# Change Operator to Airline_Operator           5268
# Change Type to Aircraft_Type                  5268
# Change Registration to Registration_Number    5268
# Change Aboard to People_Aboard                5268
# Change Fatalities to Fatalities_Aboard        5268
# Change Ground to Ground_Fatalities            5268
# Change Summary to Event_Info.s                5268
# dtype: int64

# %%
#2.15
stats.drop(['Date', 'Time', 'Flight #', 'Route', 'Registration_Number', 'cn/In', 'Change Summary to Event_Info.s'], axis=1, inplace=True)

# %% [markdown]
# # Converting

# %%
#2.17
label_encoder = LabelEncoder()

crashes['Change Operator to Airline_Operator'] = label_encoder.fit_transform(crashes['Change Operator to Airline_Operator'])
crashes['Change Type to Aircraft_Type'] = label_encoder.fit_transform(crashes['Change Type to Aircraft_Type'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
pd.get_dummies(crashes['Change Location to Crash_Location'].apply(lambda x: "opp_" + x))
crashes['Change Location to Crash_Location'] = crashes['Change Location to Crash_Location'].apply(lambda x: "opp_" + x)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9852/2384683989.py in <module>
# ----> 1 pd.get_dummies(crashes['Change Location to Crash_Location'].apply(lambda x: "opp_" + x))
#       2 crashes['Change Location to Crash_Location'] = crashes['Change Location to Crash_Location'].apply(lambda x: "opp_" + x)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ...

# %% [markdown]
# # same scale

# %%
#2.18
scaler = MinMaxScaler()
 
scaled = scaler.fit_transform(df.to_numpy())
scaled = pd.DataFrame(scaled, columns=['Date',
                                                       'Time',
                                                       'Location',
                                                       'Operator',
                                                       'Flight #',
                                                       'Change Location to Crash_Location',
                                                       'Change Operator to Airline_Operator',
                                                       'Change Type to Aircraft_Type',
                                                       'Change Registration to Registration_Number',
                                                       'Change Aboard to People_Aboard',
                                                       'Change Fatalities to Fatalities_Aboard',
                                                       'Change Ground to Ground_Fatalities',
                                                       'Change Summary to Event_Info.s'])
 
print("Scaled Dataset Using MinMaxScaler")
df_scaled.head()

# %% [markdown]
# # 2.19

# %%
crashes_clean = pd.concat([crashes, pd.get_dummies(crashes['Team']), pd.get_dummies(crashes['Opponent'])], axis=1)
crashes_clean.head(10)
